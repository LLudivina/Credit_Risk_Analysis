# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from collections import Counter

# %%
# Generate imbalanced dataset
X, y = make_blobs(n_samples=[600, 60], random_state=1, cluster_std=5)
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()

# %%
# Normal train-test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
Counter(y_train)
# Out:
# Counter({0: 451, 1: 44})

# %% [markdown]
# ## Random Oversampling

# %%
# implement random oversampling
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)

Counter(y_resampled)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33892\736110660.py in <module>
#       2 from imblearn.over_sampling import RandomOverSampler
#       3 ros = RandomOverSampler(random_state=1)
# ----> 4 X_resampled, y_resampled = ros.fit_resample(X_train, y_train)
#       5
#       6 Counter(y_resampled)
#
# c:\Users\calla\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      75         check_classification_targets(y)
#      76         arrays_transformer = ArraysTransformer(X, y)
# ---> 77         X, y, binarize_y = self._check_X_y(X, y)
#      78
#      79         self.sampling_strategy_ = check_sampling_strategy(
#
# c:\Users\calla\anaconda3\envs\PythonData\envs\mlenv\lib\site-packages\imblearn\over_sampling\_random_over_sampler.py in _check_X_y(self, X, y)
#      77     def _check_X_y(self, X, y):
#      78         y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# ---> 79         X, y = self._validate_data(
#      80             X, y, reset=True, accept_sparse=["csr", "csc"], dtype=None,
#      81             force_all_finite=False,
#
# AttributeError: 'RandomOverSampler' object has no attribute '_validate_data'

# %%
# Logistic regression using random oversampled data
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[131,  18],
#        [  1,  15]])

# %%
from sklearn.metrics import balanced_accuracy_score

balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9083473154362416

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.99      0.88      0.94      0.93      0.91      0.82       149
#           1       0.45      0.94      0.88      0.61      0.91      0.83        16
#
# avg / total       0.94      0.88      0.93      0.90      0.91      0.82       165

# %% [markdown]
# ## SMOTE

# %%
from imblearn.over_sampling import SMOTE
X_resampled, y_resampled = SMOTE(random_state=1, sampling_strategy='auto').fit_resample(
    X_train, y_train
)
Counter(y_resampled)
# Out:
# Counter({0: 451, 1: 451})

# %%
model = LogisticRegression(solver='lbfgs', random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %%
# Calculated the balanced accuracy score
y_pred = model.predict(X_test)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9150587248322148

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[133,  16],
#        [  1,  15]])

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.99      0.89      0.94      0.94      0.91      0.83       149
#           1       0.48      0.94      0.89      0.64      0.91      0.84        16
#
# avg / total       0.94      0.90      0.93      0.91      0.91      0.83       165
